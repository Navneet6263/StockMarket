# %% [markdown]
# # Daily Bhavcopy Loader (NSE + BSE)
#
# Use this notebook to pull daily bhavcopy data from NSE and BSE.
# If you hit a 403, try again or check your network. NSE often blocks requests without headers.

# %%
from pathlib import Path
import sys

repo_root = Path('..').resolve()
sys.path.append(str(repo_root / 'services' / 'api'))

from app.data_sources import fetch_bhavcopy, fetch_latest_bhavcopy

# %%
# Example: latest available NSE and BSE files
nse = fetch_latest_bhavcopy('NSE')
bse = fetch_latest_bhavcopy('BSE')

nse.df.head()

# %%
bse.df.head()

# %%
# Example: a specific date (YYYY, M, D)
# nse_specific = fetch_bhavcopy('NSE', date(2024, 1, 2))
# bse_specific = fetch_bhavcopy('BSE', date(2024, 1, 2))
